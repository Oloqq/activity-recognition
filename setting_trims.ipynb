# %%
# %load_ext autoreload

# %%
import pandas as pd
# %autoreload
from recognizer.raw_samples import *

rawdata = "data/raw"
unpacked = "data/unpacked/"

# %%
# %autoreload
from recognizer.raw_samples import *

sample = load_raw_sample("data/unpacked/wchodzenie_100mhz-2023-10-14_16-39-26", "wchodzenie")

# %%
# %autoreload
from recognizer.raw_samples import *
import pickle

suite = load_raw_suite("data/unpacked")
with open("data/RawSample/batch1.pkl", "wb") as f:
    pickle.dump(suite, f)

# %%
# from utils import unpack_dir

# unpack_dir("data/batch9", "data/validation")

# %%
# %autoreload
from recognizer.setting_trim import write_trims_for_suite
write_trims_for_suite("data/unpacked")
# Out:
# Sample length: 92
# Showing data/unpacked\chodzenie_reka-2023-10-18_17-14-22 with interval 10
