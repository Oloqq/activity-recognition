# %%
# %autoreload
from recognizer.raw_samples import *
from models.utils import *

sample = load_raw_sample("data/train/siadanie-2023-12-04_18-11-14/", "siada")[0]

print(sample)
print(sample.accelerometer)
sample.resample(0.1)
sample.showAccPlot(256)

print(ACTIVITIES.get(sample.activity))
# Out:
# Sample 10: siada
#              time         z         y         x
# 626    6005992600  0.019815  0.004367 -0.098410
# 627    6015586800  0.035300  0.001251 -0.094559
# 628    6025181700  0.036382 -0.013523 -0.104565
# 629    6034775800  0.070404 -0.027973 -0.104536
# 630    6044369400  0.070767 -0.025617 -0.101707
# ...           ...       ...       ...       ...
# 1074  10304212600 -0.027752  0.020857  0.087354
# 1075  10313806900 -0.020835 -0.003190  0.120347
# 1076  10323401800 -0.011304 -0.029363  0.145719
# 1077  10332996100  0.024158 -0.041103  0.139966
# 1078  10342589500  0.071092 -0.012802  0.120088
#
# [453 rows x 4 columns]
# (256, 4)
# 4

# %%
sample.resample(0.1)
sample.showAccPlot(256)
# Out:
# (256, 4)

# %%
sample = load_raw_sample("data/unpacked/wchodzenie-2023-10-18_21-37-04/", "wchod")[0]
sample.graph((3, 4))

# %%
sample.showAccPlot(128)
# Out:
# (128, 4)
