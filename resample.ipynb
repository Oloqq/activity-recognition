# %%
# %autoreload
from copy import deepcopy
from recognizer.raw_samples import *

# sample = load_raw_sample("data/unpacked/upadek-2023-10-11_15-52-37/", "upadek")
sample_org = load_raw_sample("data/unpacked/chodzenie-2023-10-11_12-43-28/", "w")[0]

compare_on_domain = (3.75, 4)

# sample_org.plot_sensor_data(sample_org.gyro, "Gyroscope Data", compare_on_domain)
sample_org.graph(compare_on_domain)

# %%
# %autoreload
from recognizer.raw_samples import *

sample = deepcopy(sample_org)

print(sample.gyro.head())
print(sample.gyro.shape)
sample.resample(0.2)
print("-------------------")
print(sample.gyro.shape)

print(sample.gyro.head())

# sample.plot_sensor_data(sample.gyro, "Gyroscope Data", compare_on_domain)
sample.graph(compare_on_domain)
# Out:
#            time         z         y         x
# 160  3014091500  2.268750  0.803000  0.313913
# 161  3032929800  3.243625 -0.123062 -0.744012
# 162  3051767800  4.081687 -0.656975 -1.631025
# 163  3070605800  5.633237 -0.694925 -1.343925
# 164  3089444100  6.281962  4.361775  0.230862
# (4109, 4)
# -------------------
# (15479, 4)
#          time         z         y         x
# 0  3010000000  2.268750  0.803000  0.313913
# 1  3015000000  2.512469  0.571484  0.049431
# 2  3020000000  2.756187  0.339969 -0.215050
# 3  3025000000  2.999906  0.108453 -0.479531
# 4  3030000000  3.243625 -0.123062 -0.744012
